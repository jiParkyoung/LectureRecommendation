# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/텍마
# Out:
# /content/drive/My Drive/텍마

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
from gensim.summarization.summarizer import summarize
np.random.seed(seed=0)

# %%
data = pd.read_excel('lecture_reviews.xlsx')
data
# Out:
#       Unnamed: 0    lecture_code lecture_name professor_name  \
# 0              0  0000-1-0221-01      과학철학의이해            박신화
# 1              2  0000-1-0355-02       기초영어회화            브라질
# 2              3  0000-1-0387-01           농구            박찬숙
# 3              4  0000-1-0670-01         법과생활            손명지
# 4              5  0000-1-0709-01           볼링            박인혜
# ...          ...             ...          ...            ...
# 1585        1947  H040-3-9151-01         기계학습            이상민
# 1586        1949  H040-3-9617-01      실험설계및분석            박규동
# 1587        1950  H040-4-3117-01      ICT융합전략            최점기
# 1588        1951  H040-4-8565-01    빅데이터기획분석론            이상민
# 1589        1952  H040-4-9925-01       데이터시각화            조재희
#
#                                         lecture_reviews
# 0     발표 많이 하면 에이쁠 받습니다. 본인이 발표 하는걸 좋아하지 않는다면 점수 받기 ...
# 1     학기 중에 과제 꽤 많앗는데 그거를 바탕으로 꾸준히 복습해 두시면 시험을 잘 볼 수...
# 2     농구좋아하시는분이면 무조건 추천필기와 실기로 시험봅니다. 훈련이 조금 힘들 수 있지...
# 3     시험도 크게 어렵진 않고 인생 살아가는데 큰 도움이 됩니다. 꼭꼭꼭 들으세요. 우리...
# 4     수강신청 성공하고 가서 볼링만 치면 나옴걍 개꿀강의 무엇보다 교수님이 너무 좋으심....
# ...                                                 ...
# 1585  수업 매우 좋아요. 정보융합학부면 졸업전에는 꼭 들어야 하는 수업. 수업 퀄리티는 ...
# 1586  수업이 매우 좋아요. 정보융합학부라면 필수로 수강해야 합니다. 가져가는게 많습니다....
# 1587  중간고사는 레포트로 대체 기말고사도 레포트로 대체레포트 가이드라인은 교수님이 제시해...
# 1588  내용도 유익하고 편하게 들을 수 있는 강의라 너무 좋았습니다. 우선 격주 비대면 수...
# 1589  학기 데사개 수업 열심히 들은 학생이라면 잘 따라올 수 있어요. 연장선상의 느낌입니...
#
# [1590 rows x 5 columns]

# %% [markdown]
# ## 추출요약

# %%
data['extractive'] = ''
for i in data.index :
  try:
    data['extractive'][i] = summarize(data['lecture_reviews'][i], word_count=10)
  except ValueError:
    data['extractive'][i] = data['lecture_reviews'][i]

  if data['extractive'][i] == '':
      data['extractive'][i] = data['lecture_reviews'][i]

data = data.drop(['Unnamed: 0'], axis=1)
data
# Out:
#         lecture_code lecture_name professor_name  \
# 0     0000-1-0221-01      과학철학의이해            박신화
# 1     0000-1-0355-02       기초영어회화            브라질
# 2     0000-1-0387-01           농구            박찬숙
# 3     0000-1-0670-01         법과생활            손명지
# 4     0000-1-0709-01           볼링            박인혜
# ...              ...          ...            ...
# 1585  H040-3-9151-01         기계학습            이상민
# 1586  H040-3-9617-01      실험설계및분석            박규동
# 1587  H040-4-3117-01      ICT융합전략            최점기
# 1588  H040-4-8565-01    빅데이터기획분석론            이상민
# 1589  H040-4-9925-01       데이터시각화            조재희
#
#                                         lecture_reviews  \
# 0     발표 많이 하면 에이쁠 받습니다. 본인이 발표 하는걸 좋아하지 않는다면 점수 받기 ...
# 1     학기 중에 과제 꽤 많앗는데 그거를 바탕으로 꾸준히 복습해 두시면 시험을 잘 볼 수...
# 2     농구좋아하시는분이면 무조건 추천필기와 실기로 시험봅니다. 훈련이 조금 힘들 수 있지...
# 3     시험도 크게 어렵진 않고 인생 살아가는데 큰 도움이 됩니다. 꼭꼭꼭 들으세요. 우리...
# 4     수강신청 성공하고 가서 볼링만 치면 나옴걍 개꿀강의 무엇보다 교수님이 너무 좋으심....
# ...                                                 ...
# 1585  수업 매우 좋아요. 정보융합학부면 졸업전에는 꼭 들어야 하는 수업. 수업 퀄리티는 ...
# 1586  수업이 매우 좋아요. 정보융합학부라면 필수로 수강해야 합니다. 가져가는게 많습니다....
# 1587  중간고사는 레포트로 대체 기말고사도 레포트로 대체레포트 가이드라인은 교수님이 제시해...
# 1588  내용도 유익하고 편하게 들을 수 있는 강의라 너무 좋았습니다. 우선 격주 비대면 수...
# 1589  학기 데사개 수업 열심히 들은 학생이라면 잘 따라올 수 있어요. 연장선상의 느낌입니...
#
#                                              extractive
# 0               그리고 가면 갈수록 내용이 어려워져서 초반에 발표를 많이 하면 좋아요.
# 1     학기 중에 과제 꽤 많앗는데 그거를 바탕으로 꾸준히 복습해 두시면 시험을 잘 볼 수...
# 2     훈련이 조금 힘들 수 있지만 그만큼 재미있습니다.\n농구 좋아하시면 강추 게임 위주...
# 3     시험은 강의만 열심히 들으면 잘 볼 수 있습니다.\n시험은 단답형 문제 위주로 나오...
# 4     볼링 도 못쳤는데 교수님이 알려주신대로 했더니 점수도 많이 올랐고 자세도 많이 좋아...
# ...                                                 ...
# 1585
# 1586
# 1587  중간고사는 레포트로 대체 기말고사도 레포트로 대체레포트 가이드라인은 교수님이 제시해...
# 1588  중간고사는 시험범위대로 시험을 치뤘고 기말에는 영어논문을 하나 선정하여 발표하는 것...
# 1589  학기 데사개 수업 열심히 들은 학생이라면 잘 따라올 수 있어요.\n교수님 매우 열정...
#
# [1590 rows x 5 columns]

# %%
data.to_excel('data_extractive_10.xlsx')
